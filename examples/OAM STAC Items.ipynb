# %%
# %load_ext autoreload
# %autoreload 2

# %%
import logging
from concurrent.futures import ThreadPoolExecutor, as_completed

from pystac import Item

from stactools.hotosm.exceptions import AssetNotFoundError
from stactools.hotosm.oam_metadata import OamMetadata
from stactools.hotosm.oam_metadata_client import OamMetadataClient
from stactools.hotosm.stac import create_collection, create_item

logging.basicConfig()


class QuietLogFormatter(logging.Formatter):
    """Quieter exception logging for the notebook."""

    def format(self, record):
        """Only log the last line of an exception."""
        if not record.exc_text:
            record.exc_text = self.formatException(record.exc_info)
        record.exc_text = record.exc_text.split("\n")[-1]
        return super().format(record)


hotosm_logger = logging.getLogger("stactools.hotosm")
handler = logging.StreamHandler()
handler.setFormatter(QuietLogFormatter())
hotosm_logger.addHandler(handler)

# %%
create_collection()
# Out:
# <Collection id=openaerialmap>

# %%
client = OamMetadataClient.new()

# %%
total = client.get_count()

oam_items = client.get_all_items()


def process_metadata_to_stac(metadata: OamMetadata) -> Item:
    """Worker function to convert metadata to STAC."""
    # correct common issues in metadata, e.g., incorrect SPDX license identifiers
    oam_item_sanitized = oam_item.sanitize()
    return create_item(oam_item_sanitized)


stac_items: list[Item] = []
failures: list[str] = []
with ThreadPoolExecutor() as pool:
    futures = {}

    for oam_item in oam_items:
        future = pool.submit(process_metadata_to_stac, oam_item)
        futures[future] = oam_item

    for i, future in enumerate(as_completed(futures)):
        if i % 1000 == 0:
            print(f"Item {i}/{total}")

        oam_item = futures[future]

        try:
            stac_item = future.result()
        except AssetNotFoundError:
            print(f"Could not generate STAC Item for {oam_item.id}")
            failures.append(oam_item)
        else:
            stac_items.append(stac_item)
# Out:
# Could not parse id=59e62b773d6412ef72209353
# TypeError: fromisoformat: argument must be str
# ERROR:stactools.hotosm.oam_metadata_client:Could not parse id=59e62b773d6412ef72209353
# TypeError: fromisoformat: argument must be str
# Could not parse id=59e62b773d6412ef722093b7
# TypeError: fromisoformat: argument must be str
# ERROR:stactools.hotosm.oam_metadata_client:Could not parse id=59e62b773d6412ef722093b7
# TypeError: fromisoformat: argument must be str
# Could not parse id=59e62b743d6412ef722091bd
# TypeError: fromisoformat: argument must be str
# ERROR:stactools.hotosm.oam_metadata_client:Could not parse id=59e62b743d6412ef722091bd
# TypeError: fromisoformat: argument must be str
# Item 0/17750
# Item 1000/17750
# Item 2000/17750
# Item 3000/17750
# Item 4000/17750
# Item 5000/17750
# Item 6000/17750
# Item 7000/17750
# Item 8000/17750
# Item 9000/17750
# Item 10000/17750
# Item 11000/17750
# Item 12000/17750
# Item 13000/17750
# Item 14000/17750
# Item 15000/17750
# Item 16000/17750
# Item 17000/17750
# Could not generate STAC Item for 5bcf4a365a9ef7cb5d8a2bc2
# Could not generate STAC Item for 5bcf4a375a9ef7cb5d8a2c05
# Could not generate STAC Item for 5bcf4a375a9ef7cb5d8a2c2b
# Could not generate STAC Item for 5bcf4a365a9ef7cb5d8a2bdc
# Could not generate STAC Item for 5bcf4a355a9ef7cb5d8a2baa
# Could not generate STAC Item for 5bcf4a375a9ef7cb5d8a2c1f
# Could not generate STAC Item for 5bcf4a355a9ef7cb5d8a2ba0
# Could not generate STAC Item for 5bcf4a385a9ef7cb5d8a2c3e
# Could not generate STAC Item for 5bcf4a365a9ef7cb5d8a2beb
# Could not generate STAC Item for 5bcf4a375a9ef7cb5d8a2c24
# Could not generate STAC Item for 5bcf4a385a9ef7cb5d8a2c47
# Could not generate STAC Item for 5bcf4a375a9ef7cb5d8a2bff
# Could not generate STAC Item for 5bcf4a375a9ef7cb5d8a2bf1
# Could not generate STAC Item for 5bcf4a355a9ef7cb5d8a2b9b
# Could not generate STAC Item for 5bcf4a355a9ef7cb5d8a2b91
# Could not generate STAC Item for 5bcf4a375a9ef7cb5d8a2c11
# Could not generate STAC Item for 5bcf4a345a9ef7cb5d8a2b50
# Could not generate STAC Item for 5bcf4a355a9ef7cb5d8a2b7e
# Could not generate STAC Item for 5bcf4a345a9ef7cb5d8a2b3e
# Could not generate STAC Item for 5bcf4a345a9ef7cb5d8a2b44
# Could not generate STAC Item for 5bcf4a345a9ef7cb5d8a2b63
# Could not generate STAC Item for 5bcf4a345a9ef7cb5d8a2b69
# Could not generate STAC Item for 5bcf4a345a9ef7cb5d8a2b38
# Could not generate STAC Item for 5bcf4a345a9ef7cb5d8a2b56
# Could not generate STAC Item for 5bcf4a325a9ef7cb5d8a2ae9
# Could not generate STAC Item for 5bcf4a335a9ef7cb5d8a2b0a
# Could not generate STAC Item for 5bcf4a335a9ef7cb5d8a2b28
# Could not generate STAC Item for 5bcf4a335a9ef7cb5d8a2afc
# Could not generate STAC Item for 5bcf4a325a9ef7cb5d8a2aed
# Could not generate STAC Item for 60fbca545a90f10006fd2fc5
# Could not generate STAC Item for 5bcf4a335a9ef7cb5d8a2b1a
# Could not generate STAC Item for 5bcf4a325a9ef7cb5d8a2ae0
# Could not generate STAC Item for 5bcf4a335a9ef7cb5d8a2af5
# Could not generate STAC Item for 61248e5cb7012200056b5ca9
# Could not generate STAC Item for 5bcf4a335a9ef7cb5d8a2b02
# Could not generate STAC Item for 612471deb7012200056b5ca3
# Could not generate STAC Item for 5bcf4a335a9ef7cb5d8a2b18
# Could not generate STAC Item for 5bcf4a345a9ef7cb5d8a2b31
# Could not generate STAC Item for 5bcf4a385a9ef7cb5d8a2c37
# Could not generate STAC Item for 5bcf4a375a9ef7cb5d8a2c16
# Could not generate STAC Item for 660d0b08c055e600014ac432
# Could not generate STAC Item for 5bcf4a355a9ef7cb5d8a2b72
# Could not generate STAC Item for 5bcf4a345a9ef7cb5d8a2b5e
# Could not generate STAC Item for 5bcf4a365a9ef7cb5d8a2bcf
# Could not generate STAC Item for 5bcf4a365a9ef7cb5d8a2bd4
# Could not generate STAC Item for 5bcf4a335a9ef7cb5d8a2b21
# Could not generate STAC Item for 5bcf4a385a9ef7cb5d8a2c72
# Could not generate STAC Item for 5bcf4a355a9ef7cb5d8a2baf
# Could not generate STAC Item for 5bcf4a375a9ef7cb5d8a2bf9
# Could not generate STAC Item for 5bcf4a355a9ef7cb5d8a2b79
# Could not generate STAC Item for 5bcf4a355a9ef7cb5d8a2b89
# Could not generate STAC Item for 5bcf4a365a9ef7cb5d8a2bc7
# Could not generate STAC Item for 660d1166c055e600014ac439

# %%
print(f"Converted {len(stac_items)} of {total} metadata entries to STAC Items")
# Out:
# Converted 17694 of 17750 metadata entries to STAC Items

# %% [markdown]
# ### Write to NDJSON for ingestion into (PgSTAC) STAC Catalog

# %%
import json

with open("openaerialmap.ndjson", "w") as dst:
    for item in stac_items:
        item_json = json.dumps(item.to_dict())
        dst.write(f"{item_json}\n")
