# %%
# %load_ext autoreload
# %autoreload 2

# %%
import json
import logging
import time
from collections import defaultdict
from concurrent.futures import ThreadPoolExecutor, as_completed

from pystac import Item

from stactools.hotosm.exceptions import AssetNotFoundError
from stactools.hotosm.oam_metadata import OamMetadata
from stactools.hotosm.oam_metadata_client import OamMetadataClient
from stactools.hotosm.stac import create_collection, create_item

logging.basicConfig()


class QuietLogFormatter(logging.Formatter):
    """Quieter exception logging for the notebook."""

    def format(self, record):
        """Only log the last line of an exception."""
        if not record.exc_text:
            record.exc_text = self.formatException(record.exc_info)
        record.exc_text = record.exc_text.split("\n")[-1]
        return super().format(record)


hotosm_logger = logging.getLogger("stactools.hotosm")
handler = logging.StreamHandler()
handler.setFormatter(QuietLogFormatter())
hotosm_logger.addHandler(handler)

# %%
collection = create_collection()
collection
# Out:
# <Collection id=openaerialmap>

# %%
with open("./collection.json", "w") as f:
    f.write(json.dumps(collection.to_dict(), indent=2))

# %%
client = OamMetadataClient.new()

# %%
total = client.get_count()

oam_items = client.get_all_items(page_size=20_000)


def process_metadata_to_stac(metadata: OamMetadata) -> Item:
    """Worker function to convert metadata to STAC."""
    # correct common issues in metadata, e.g., incorrect SPDX license identifiers
    sanitized_metadata = metadata.sanitize()
    return create_item(sanitized_metadata)


stac_items: list[Item] = []
failures: list[tuple[OamMetadata, Exception]] = []

time1 = time.time()
with ThreadPoolExecutor() as pool:
    futures = {}

    for oam_item in oam_items:
        future = pool.submit(process_metadata_to_stac, oam_item)
        futures[future] = oam_item

    for i, future in enumerate(as_completed(futures)):
        if i % 1000 == 0:
            print(f"Item {i}/{total}")

        oam_item = futures[future]

        try:
            stac_item = future.result()
        except AssetNotFoundError as e:
            print(f"Could not generate STAC Item for {oam_item.id}")
            failures.append((oam_item, e))
        except Exception as e:
            print(f"Unexpected error occurred for {oam_item.id}!")
            failures.append((oam_item, e))
        else:
            stac_items.append(stac_item)

time2 = time.time()
print(f"Took {(time2 - time1) / 60.0:0.3f} minutes to convert catalog to STAC")
# Out:
# Could not parse id=59e62b773d6412ef72209353
# TypeError: fromisoformat: argument must be str
# ERROR:stactools.hotosm.oam_metadata_client:Could not parse id=59e62b773d6412ef72209353
# TypeError: fromisoformat: argument must be str
# Could not parse id=59e62b773d6412ef722093b7
# TypeError: fromisoformat: argument must be str
# ERROR:stactools.hotosm.oam_metadata_client:Could not parse id=59e62b773d6412ef722093b7
# TypeError: fromisoformat: argument must be str
# Could not parse id=59e62b743d6412ef722091bd
# TypeError: fromisoformat: argument must be str
# ERROR:stactools.hotosm.oam_metadata_client:Could not parse id=59e62b743d6412ef722091bd
# TypeError: fromisoformat: argument must be str
# Item 0/17790
# Could not generate STAC Item for 59e62b863d6412ef72209b56
# Could not generate STAC Item for 59e62b863d6412ef72209b54
# Could not generate STAC Item for 59e62b6f3d6412ef72208f1a
# Could not generate STAC Item for 59e62b863d6412ef72209b4f
# Could not generate STAC Item for 59e62b6f3d6412ef72208f2d
# Could not generate STAC Item for 59e62b703d6412ef72208f44
# Could not generate STAC Item for 678bbefa1b953900016c6935
# Could not generate STAC Item for 59e62b703d6412ef72208f3f
# Could not generate STAC Item for 59e62b703d6412ef72208f39
# Could not generate STAC Item for 59e62b703d6412ef72208f33
# Could not generate STAC Item for 59e62b703d6412ef72208f35
# Could not generate STAC Item for 6791aec314a89b000127627d
# Could not generate STAC Item for 67f3b4b51caa479c597a2a5e
# Could not generate STAC Item for 67f3c0931caa479c597a3dcc
# Could not generate STAC Item for 59e62b703d6412ef72208f4a
# Could not generate STAC Item for 678a87a31b953900016c6913
# Could not generate STAC Item for 679d23f8d5ec7d92c086a43b
# Could not generate STAC Item for 6802756f4419d45abd55f72a
# Could not generate STAC Item for 59e62b6f3d6412ef72208f27
# Could not generate STAC Item for 67f929fdf769c0a050dbf71c
# Could not generate STAC Item for 67f8d7c2f769c0a050dbabfb
# Could not generate STAC Item for 67b464362d1e43f5572c0291
# Could not generate STAC Item for 67b465252d1e43f5572c02d3
# Could not generate STAC Item for 678f0678b1da9700012b2480
# Could not generate STAC Item for 679aaa0b76326facfe7401cc
# Could not generate STAC Item for 679aa9c276326facfe74017f
# Could not generate STAC Item for 679aa32b76326facfe73fd71
# Could not generate STAC Item for 679aa93b76326facfe740148
# Could not generate STAC Item for 679aa05376326facfe73fa10
# Could not generate STAC Item for 6792e4598fbd620001a3d192
# Could not generate STAC Item for 67957412fec41b00017689af
# Could not generate STAC Item for 679bf3eed5ec7d92c085c590
# Could not generate STAC Item for 67af24e03d41f85c56807998
# Could not generate STAC Item for 67af1d8b3d41f85c568071bf
# Could not generate STAC Item for 678c865db320a40001889679
# Could not generate STAC Item for 67904de8b1da9700012b24a6
# Could not generate STAC Item for 67ca0d36c9e07cefe190f413
# Could not generate STAC Item for 67d20ecf67d7a1f4568bdde3
# Could not generate STAC Item for 67ee694fbc26a4d8e0d5adc5
# Could not generate STAC Item for 679d5c25d5ec7d92c086d822
# Could not generate STAC Item for 679d5455d5ec7d92c086d2ca
# Could not generate STAC Item for 6796ed2a86901b0001384413
# Could not generate STAC Item for 67c12ebe1e8d5102b354eb42
# Could not generate STAC Item for 67a44a7fd2f6f0d1910638de
# Could not generate STAC Item for 67a4940cd2f6f0d191067d7a
# Could not generate STAC Item for 678dc0d2e3e61000012deddf
# Could not generate STAC Item for 67c270abaaf1e28d21d2f146
# Could not generate STAC Item for 67ba21ebec9237a9ebd36829
# Could not generate STAC Item for 67da9bad7725741fc91b2eee
# Could not generate STAC Item for 67b31db1e0f9dbf5fffdb62a
# Could not generate STAC Item for 67dc56b7d207fa7f4d74f8e9
# Item 1000/17790
# Could not generate STAC Item for 679e4409d5ec7d92c0875092
# Could not generate STAC Item for 67d90ac73d9ab746b391dd20
# Could not generate STAC Item for 67d389ad29c3f8a675743052
# Could not generate STAC Item for 67896d481b953900016c690c
# Could not generate STAC Item for 678fe1b3b1da9700012b2491
# Could not generate STAC Item for 67af01043d41f85c56803ec6
# Could not generate STAC Item for 678cd28bb320a40001889681
# Could not generate STAC Item for 67fc4a48c89236d7d53874d5
# Unexpected error occurred for 634c39e139ec3b000787e34d!
# Could not generate STAC Item for 6796b439fec41b00017689d7
# Could not generate STAC Item for 67a65b124a0fd0139fa015c0
# Could not generate STAC Item for 678d1816b320a4000188968c
# Could not generate STAC Item for 678c2ec81b953900016c694b
# Could not generate STAC Item for 678c21e91b953900016c6946
# Could not generate STAC Item for 67bb88146c97d8dc7ad58b6a
# Could not generate STAC Item for 67aaddf3f0bc0e6f2ff66bc5
# Could not generate STAC Item for 67cf8c9e39bbbf913bbfff88
# Could not generate STAC Item for 67f5506164f766dda71a2e52
# Could not generate STAC Item for 67f01a065d8e664130586bca
# Could not generate STAC Item for 67f44fdca8488cf9bebb5356
# Could not generate STAC Item for 67e428fa305c6aa345b84cc1
# Could not generate STAC Item for 67ebfaa5bc26a4d8e0d22aa4
# Could not generate STAC Item for 67f137935d8e664130590bea
# Could not generate STAC Item for 67a4bc04d2f6f0d19106a897
# Could not generate STAC Item for 6800d9d60859d5432c0616c6
# Could not generate STAC Item for 67b3951a52200bd46b3a289f
# Could not generate STAC Item for 67aefb4d3d41f85c56803679
# Could not generate STAC Item for 67c85126c9e07cefe18efe5a
# Could not generate STAC Item for 67eff9155d8e66413058459c
# Could not generate STAC Item for 67eff7de5d8e66413058451e
# Could not generate STAC Item for 67eff72e5d8e664130584458
# Could not generate STAC Item for 67a2c157dc1faacd383842c5
# Could not generate STAC Item for 67c12fe61e8d5102b354ec2a
# Could not generate STAC Item for 67e42a49305c6aa345b84ebe
# Could not generate STAC Item for 67e3c21908fb36a03a0bad55
# Could not generate STAC Item for 67b5231fe922fa089f1d4faa
# Could not generate STAC Item for 67b5231fe922fa089f1d4fa5
# Could not generate STAC Item for 67b5309907a0a0a9cee94723
# Could not generate STAC Item for 67914ffa58af4b00017c6ded
# Could not generate STAC Item for 67a2c740dc1faacd38384a49
# Could not generate STAC Item for 67d3e69529c3f8a675747520
# Could not generate STAC Item for 67a2c6a8dc1faacd38384a14
# Could not generate STAC Item for 67a2c6a8dc1faacd38384a0f
# Could not generate STAC Item for 67a2c113dc1faacd38384251
# Could not generate STAC Item for 67a2c0fedc1faacd383841f8
# Could not generate STAC Item for 67a2c5a4dc1faacd383849f8
# Could not generate STAC Item for 67a2c65adc1faacd38384a0a
# Item 2000/17790
# Could not generate STAC Item for 67d45a94c8ccd45a00a9490d
# Could not generate STAC Item for 678e8a78b1da9700012b246a
# Could not generate STAC Item for 67926a30c8e67f00015bb303
# Could not generate STAC Item for 6793c5ef8fbd620001a3d1ac
# WARNING:rasterio._env:CPLE_AppDefined in CRS EPSG:4140 is deprecated. Its non-deprecated replacement EPSG:4617 will be used instead. To use the original CRS, set the OSR_USE_NON_DEPRECATED configuration option to NO.
# Could not generate STAC Item for 5a9ffc185a9ef7cb5da92bef
# Could not generate STAC Item for 649afe214395b26cd2af7ab3
# Could not generate STAC Item for 67e953bfcaf9fa99f53a502c
# Could not generate STAC Item for 5a9ffc185a9ef7cb5da92bea
# Could not generate STAC Item for 67bb65366c97d8dc7ad569f5
# Could not generate STAC Item for 67d44e8ac8ccd45a00a935db
# Could not generate STAC Item for 67d991c27725741fc9199512
# Could not generate STAC Item for 67d889a51325d3f9345c9a8c
# Could not generate STAC Item for 67efef825d8e66413058391b
# Could not generate STAC Item for 67ef3bd5ca6f76f97a4b02e7
# Could not generate STAC Item for 67e42a25305c6aa345b84e48
# Could not generate STAC Item for 649b3fe49ca545000157f81f
# Could not generate STAC Item for 67eab77a3486d9a910f3286a
# Could not generate STAC Item for 67ebdf693486d9a910f45327
# Could not generate STAC Item for 67c75577e364a9da596a8474
# Could not generate STAC Item for 678c64ffb320a40001889674
# Could not generate STAC Item for 678fcbfcb1da9700012b248a
# Could not generate STAC Item for 67da1afb7725741fc91aad63
# Could not generate STAC Item for 67aadf16f0bc0e6f2ff66f78
# Could not generate STAC Item for 67e42289305c6aa345b83d74
# Could not generate STAC Item for 5a9ffc185a9ef7cb5da92be7
# Could not generate STAC Item for 67da1ac67725741fc91aad1f
# Could not generate STAC Item for 67be754cacdf180d378043a4
# Could not generate STAC Item for 67c0dd971e8d5102b354a905
# WARNING:rasterio._env:CPLE_AppDefined in The definition of geographic CRS EPSG:4293 got from GeoTIFF keys is not the same as the one from the EPSG registry, which may cause issues during reprojection operations. Set GTIFF_SRS_SOURCE configuration option to EPSG to use official parameters (overriding the ones from GeoTIFF keys), or to GEOKEYS to use custom values from GeoTIFF keys and drop the EPSG code.
# WARNING:rasterio._env:CPLE_AppDefined in The definition of geographic CRS EPSG:4293 got from GeoTIFF keys is not the same as the one from the EPSG registry, which may cause issues during reprojection operations. Set GTIFF_SRS_SOURCE configuration option to EPSG to use official parameters (overriding the ones from GeoTIFF keys), or to GEOKEYS to use custom values from GeoTIFF keys and drop the EPSG code.

# %%
print(f"Converted {len(stac_items)} of {total} metadata entries to STAC Items")

# %% [markdown]
# ## Deduplicate on Item ID

# %%
dupe_count: dict[str, int] = defaultdict(lambda: 0)
distinct_items = {}
for item in stac_items:
    if (other_item := distinct_items.get(item.id)) is not None:
        dupe_count[item.id] += 1
        item_created = item.assets["metadata"].extra_fields["updated"]
        other_created = other_item.assets["metadata"].extra_fields["updated"]
        if item_created > other_created:
            distinct_items[item.id] = item
    else:
        distinct_items[item.id] = item

# %%
print(f"Deduplicated from {len(stac_items)} to {len(distinct_items)} Items")
print(
    f"There were {len(dupe_count)} duplicates ranging between "
    f"{min(dupe_count.values())} to {max(dupe_count.values())} duplicates "
    f"(mean={sum(dupe_count.values()) / len(dupe_count):0.3f} dupes per ID)"
)

# %% [markdown]
# ### Write to NDJSON for ingestion into (PgSTAC) STAC Catalog

# %%
import datetime as dt
import json

destination = f"openaerialmap-{dt.datetime.now().strftime('%Y%m%dT%H%M%S')}.ndjson"
with open(destination, "w") as dst:
    for item in distinct_items.values():
        item_json = json.dumps(item.to_dict())
        dst.write(f"{item_json}\n")
