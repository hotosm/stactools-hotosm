# %%
# %load_ext autoreload
# %autoreload 2

# %%
import logging
from concurrent.futures import ThreadPoolExecutor, as_completed

from pystac import Item

from stactools.hotosm.exceptions import AssetNotFoundError
from stactools.hotosm.oam_metadata import OamMetadata
from stactools.hotosm.oam_metadata_client import OamMetadataClient
from stactools.hotosm.stac import create_collection, create_item

logging.basicConfig()

# %%
create_collection()
# Out:
# <Collection id=openaerialmap>

# %%
client = OamMetadataClient.new()

# %%
total = client.get_count()

oam_items = client.get_all_items()


def process_metadata_to_stac(metadata: OamMetadata) -> Item:
    """Worker function to convert metadata to STAC."""
    # correct common issues in metadata, e.g., incorrect SPDX license identifiers
    oam_item_sanitized = oam_item.sanitize()
    return create_item(oam_item_sanitized)


stac_items = []
with ThreadPoolExecutor() as pool:
    futures = {}
    for oam_item in oam_items:
        future = pool.submit(process_metadata_to_stac, oam_item)
        futures[future] = oam_item

    for i, future in enumerate(as_completed(futures)):
        if i % 1000 == 0:
            print(f"Item {i}/{total}")

        oam_item = futures[future]

        try:
            stac_item = future.result()
        except AssetNotFoundError:
            logging.exception(f"Could not generate STAC Item for {oam_item.id}")
        else:
            stac_items.append(stac_item)
# Out:
# ERROR:stactools.hotosm.oam_metadata_client:Could not parse id=59e62b773d6412ef72209353
# Traceback (most recent call last):
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/oam_metadata_client.py", line 101, in get_items
#     results.append(self._parse_result(result))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/oam_metadata_client.py", line 46, in _parse_result
#     acquisition_start=dt.datetime.fromisoformat(result["acquisition_start"]),
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: fromisoformat: argument must be str
# ERROR:stactools.hotosm.oam_metadata_client:Could not parse id=59e62b773d6412ef722093b7
# Traceback (most recent call last):
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/oam_metadata_client.py", line 101, in get_items
#     results.append(self._parse_result(result))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/oam_metadata_client.py", line 46, in _parse_result
#     acquisition_start=dt.datetime.fromisoformat(result["acquisition_start"]),
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: fromisoformat: argument must be str
# ERROR:stactools.hotosm.oam_metadata_client:Could not parse id=59e62b743d6412ef722091bd
# Traceback (most recent call last):
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/oam_metadata_client.py", line 101, in get_items
#     results.append(self._parse_result(result))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/oam_metadata_client.py", line 46, in _parse_result
#     acquisition_start=dt.datetime.fromisoformat(result["acquisition_start"]),
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: fromisoformat: argument must be str
# Item 0/17745
# Item 1000/17745
# Item 2000/17745
# Item 3000/17745
# Item 4000/17745
# Item 5000/17745
# Item 6000/17745
# Item 7000/17745
# Item 8000/17745
# Item 9000/17745
# Item 10000/17745
# WARNING:rasterio._env:CPLE_AppDefined in The definition of geographic CRS EPSG:4326 got from GeoTIFF keys is not the same as the one from the EPSG registry, which may cause issues during reprojection operations. Set GTIFF_SRS_SOURCE configuration option to EPSG to use official parameters (overriding the ones from GeoTIFF keys), or to GEOKEYS to use custom values from GeoTIFF keys and drop the EPSG code.
# WARNING:rasterio._env:CPLE_AppDefined in The definition of geographic CRS EPSG:4284 got from GeoTIFF keys is not the same as the one from the EPSG registry, which may cause issues during reprojection operations. Set GTIFF_SRS_SOURCE configuration option to EPSG to use official parameters (overriding the ones from GeoTIFF keys), or to GEOKEYS to use custom values from GeoTIFF keys and drop the EPSG code.
# WARNING:rasterio._env:CPLE_AppDefined in The definition of geographic CRS EPSG:4284 got from GeoTIFF keys is not the same as the one from the EPSG registry, which may cause issues during reprojection operations. Set GTIFF_SRS_SOURCE configuration option to EPSG to use official parameters (overriding the ones from GeoTIFF keys), or to GEOKEYS to use custom values from GeoTIFF keys and drop the EPSG code.
# WARNING:rasterio._env:CPLE_AppDefined in The definition of geographic CRS EPSG:4284 got from GeoTIFF keys is not the same as the one from the EPSG registry, which may cause issues during reprojection operations. Set GTIFF_SRS_SOURCE configuration option to EPSG to use official parameters (overriding the ones from GeoTIFF keys), or to GEOKEYS to use custom values from GeoTIFF keys and drop the EPSG code.
# Item 11000/17745
# Item 12000/17745
# Item 13000/17745
# Item 14000/17745
# Item 15000/17745
# Item 16000/17745
# Item 17000/17745
# ERROR:root:Could not generate STAC Item for 5bcf4a385a9ef7cb5d8a2c66
# Traceback (most recent call last):
#   File "rasterio/_base.pyx", line 310, in rasterio._base.DatasetBase.__init__
#   File "rasterio/_base.pyx", line 221, in rasterio._base.open_dataset
#   File "rasterio/_err.pyx", line 359, in rasterio._err.exc_wrap_pointer
# rasterio._err.CPLE_HttpResponseError: HTTP response code: 404
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 202, in _add_projection_extension
#     with rasterio.open(href) as src:
#          ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/.venv/lib/python3.12/site-packages/rasterio/env.py", line 463, in wrapper
#     return f(*args, **kwds)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/.venv/lib/python3.12/site-packages/rasterio/__init__.py", line 356, in open
#     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "rasterio/_base.pyx", line 312, in rasterio._base.DatasetBase.__init__
# rasterio.errors.RasterioIOError: HTTP response code: 404
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/var/folders/g7/5vynv9md5dz_pzng6cjn6xvc0000gn/T/ipykernel_13087/3052829065.py", line 26, in <module>
#     stac_item = future.result()
#                 ^^^^^^^^^^^^^^^
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/g7/5vynv9md5dz_pzng6cjn6xvc0000gn/T/ipykernel_13087/3052829065.py", line 9, in process_metadata_to_stac
#     return create_item(oam_item_sanitized)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 187, in create_item
#     _add_projection_extension(item, ["image"])
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 205, in _add_projection_extension
#     raise AssetNotFoundError(f"Asset does not exist at {href}") from e
# stactools.hotosm.exceptions.AssetNotFoundError: Asset does not exist at http://oin-hotosm-staging.s3.amazonaws.com/202/5984519000239f00149f2ea4/0/6494d8ea-d118-40dc-acfc-9184868da540.tif
# ERROR:root:Could not generate STAC Item for 5bcf4a385a9ef7cb5d8a2c5f
# Traceback (most recent call last):
#   File "rasterio/_base.pyx", line 310, in rasterio._base.DatasetBase.__init__
#   File "rasterio/_base.pyx", line 221, in rasterio._base.open_dataset
#   File "rasterio/_err.pyx", line 359, in rasterio._err.exc_wrap_pointer
# rasterio._err.CPLE_HttpResponseError: HTTP response code: 404
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 202, in _add_projection_extension
#     with rasterio.open(href) as src:
#          ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/.venv/lib/python3.12/site-packages/rasterio/env.py", line 463, in wrapper
#     return f(*args, **kwds)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/.venv/lib/python3.12/site-packages/rasterio/__init__.py", line 356, in open
#     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "rasterio/_base.pyx", line 312, in rasterio._base.DatasetBase.__init__
# rasterio.errors.RasterioIOError: HTTP response code: 404
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/var/folders/g7/5vynv9md5dz_pzng6cjn6xvc0000gn/T/ipykernel_13087/3052829065.py", line 26, in <module>
#     stac_item = future.result()
#                 ^^^^^^^^^^^^^^^
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/g7/5vynv9md5dz_pzng6cjn6xvc0000gn/T/ipykernel_13087/3052829065.py", line 9, in process_metadata_to_stac
#     return create_item(oam_item_sanitized)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 187, in create_item
#     _add_projection_extension(item, ["image"])
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 205, in _add_projection_extension
#     raise AssetNotFoundError(f"Asset does not exist at {href}") from e
# stactools.hotosm.exceptions.AssetNotFoundError: Asset does not exist at http://oin-hotosm-staging.s3.amazonaws.com/202/5984519000239f00149f2ea4/0/6494d8ea-d118-40dc-acfc-9184868da540.tif
# ERROR:root:Could not generate STAC Item for 5bcf4a385a9ef7cb5d8a2c47
# Traceback (most recent call last):
#   File "rasterio/_base.pyx", line 310, in rasterio._base.DatasetBase.__init__
#   File "rasterio/_base.pyx", line 221, in rasterio._base.open_dataset
#   File "rasterio/_err.pyx", line 359, in rasterio._err.exc_wrap_pointer
# rasterio._err.CPLE_HttpResponseError: HTTP response code: 404
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 202, in _add_projection_extension
#     with rasterio.open(href) as src:
#          ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/.venv/lib/python3.12/site-packages/rasterio/env.py", line 463, in wrapper
#     return f(*args, **kwds)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/.venv/lib/python3.12/site-packages/rasterio/__init__.py", line 356, in open
#     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "rasterio/_base.pyx", line 312, in rasterio._base.DatasetBase.__init__
# rasterio.errors.RasterioIOError: HTTP response code: 404
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/var/folders/g7/5vynv9md5dz_pzng6cjn6xvc0000gn/T/ipykernel_13087/3052829065.py", line 26, in <module>
#     stac_item = future.result()
#                 ^^^^^^^^^^^^^^^
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/g7/5vynv9md5dz_pzng6cjn6xvc0000gn/T/ipykernel_13087/3052829065.py", line 9, in process_metadata_to_stac
#     return create_item(oam_item_sanitized)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 187, in create_item
#     _add_projection_extension(item, ["image"])
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 205, in _add_projection_extension
#     raise AssetNotFoundError(f"Asset does not exist at {href}") from e
# stactools.hotosm.exceptions.AssetNotFoundError: Asset does not exist at http://oin-hotosm-staging.s3.amazonaws.com/202/5984519000239f00149f2ea4/0/6494d8ea-d118-40dc-acfc-9184868da540.tif
# ERROR:root:Could not generate STAC Item for 5bcf4a375a9ef7cb5d8a2c11
# Traceback (most recent call last):
#   File "rasterio/_base.pyx", line 310, in rasterio._base.DatasetBase.__init__
#   File "rasterio/_base.pyx", line 221, in rasterio._base.open_dataset
#   File "rasterio/_err.pyx", line 359, in rasterio._err.exc_wrap_pointer
# rasterio._err.CPLE_HttpResponseError: HTTP response code: 404
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 202, in _add_projection_extension
#     with rasterio.open(href) as src:
#          ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/.venv/lib/python3.12/site-packages/rasterio/env.py", line 463, in wrapper
#     return f(*args, **kwds)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/.venv/lib/python3.12/site-packages/rasterio/__init__.py", line 356, in open
#     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "rasterio/_base.pyx", line 312, in rasterio._base.DatasetBase.__init__
# rasterio.errors.RasterioIOError: HTTP response code: 404
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/var/folders/g7/5vynv9md5dz_pzng6cjn6xvc0000gn/T/ipykernel_13087/3052829065.py", line 26, in <module>
#     stac_item = future.result()
#                 ^^^^^^^^^^^^^^^
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/g7/5vynv9md5dz_pzng6cjn6xvc0000gn/T/ipykernel_13087/3052829065.py", line 9, in process_metadata_to_stac
#     return create_item(oam_item_sanitized)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 187, in create_item
#     _add_projection_extension(item, ["image"])
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 205, in _add_projection_extension
#     raise AssetNotFoundError(f"Asset does not exist at {href}") from e
# stactools.hotosm.exceptions.AssetNotFoundError: Asset does not exist at http://oin-hotosm-staging.s3.amazonaws.com/202/5984513200239f00149f2e9d/0/d56275a6-f6fd-4413-9af3-1cde35527cae.tif
# ERROR:root:Could not generate STAC Item for 5bcf4a385a9ef7cb5d8a2c53
# Traceback (most recent call last):
#   File "rasterio/_base.pyx", line 310, in rasterio._base.DatasetBase.__init__
#   File "rasterio/_base.pyx", line 221, in rasterio._base.open_dataset
#   File "rasterio/_err.pyx", line 359, in rasterio._err.exc_wrap_pointer
# rasterio._err.CPLE_HttpResponseError: HTTP response code: 404
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 202, in _add_projection_extension
#     with rasterio.open(href) as src:
#          ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/.venv/lib/python3.12/site-packages/rasterio/env.py", line 463, in wrapper
#     return f(*args, **kwds)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/.venv/lib/python3.12/site-packages/rasterio/__init__.py", line 356, in open
#     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "rasterio/_base.pyx", line 312, in rasterio._base.DatasetBase.__init__
# rasterio.errors.RasterioIOError: HTTP response code: 404
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/var/folders/g7/5vynv9md5dz_pzng6cjn6xvc0000gn/T/ipykernel_13087/3052829065.py", line 26, in <module>
#     stac_item = future.result()
#                 ^^^^^^^^^^^^^^^
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/g7/5vynv9md5dz_pzng6cjn6xvc0000gn/T/ipykernel_13087/3052829065.py", line 9, in process_metadata_to_stac
#     return create_item(oam_item_sanitized)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 187, in create_item
#     _add_projection_extension(item, ["image"])
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 205, in _add_projection_extension
#     raise AssetNotFoundError(f"Asset does not exist at {href}") from e
# stactools.hotosm.exceptions.AssetNotFoundError: Asset does not exist at http://oin-hotosm-staging.s3.amazonaws.com/202/5984519000239f00149f2ea4/0/6494d8ea-d118-40dc-acfc-9184868da540.tif
# ERROR:root:Could not generate STAC Item for 5bcf4a385a9ef7cb5d8a2c6e
# Traceback (most recent call last):
#   File "rasterio/_base.pyx", line 310, in rasterio._base.DatasetBase.__init__
#   File "rasterio/_base.pyx", line 221, in rasterio._base.open_dataset
#   File "rasterio/_err.pyx", line 359, in rasterio._err.exc_wrap_pointer
# rasterio._err.CPLE_HttpResponseError: HTTP response code: 404
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 202, in _add_projection_extension
#     with rasterio.open(href) as src:
#          ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/.venv/lib/python3.12/site-packages/rasterio/env.py", line 463, in wrapper
#     return f(*args, **kwds)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/.venv/lib/python3.12/site-packages/rasterio/__init__.py", line 356, in open
#     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "rasterio/_base.pyx", line 312, in rasterio._base.DatasetBase.__init__
# rasterio.errors.RasterioIOError: HTTP response code: 404
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/var/folders/g7/5vynv9md5dz_pzng6cjn6xvc0000gn/T/ipykernel_13087/3052829065.py", line 26, in <module>
#     stac_item = future.result()
#                 ^^^^^^^^^^^^^^^
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/g7/5vynv9md5dz_pzng6cjn6xvc0000gn/T/ipykernel_13087/3052829065.py", line 9, in process_metadata_to_stac
#     return create_item(oam_item_sanitized)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 187, in create_item
#     _add_projection_extension(item, ["image"])
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 205, in _add_projection_extension
#     raise AssetNotFoundError(f"Asset does not exist at {href}") from e
# stactools.hotosm.exceptions.AssetNotFoundError: Asset does not exist at http://oin-hotosm-staging.s3.amazonaws.com/202/5984519000239f00149f2ea4/0/6494d8ea-d118-40dc-acfc-9184868da540.tif
# ERROR:root:Could not generate STAC Item for 5bcf4a385a9ef7cb5d8a2c4d
# Traceback (most recent call last):
#   File "rasterio/_base.pyx", line 310, in rasterio._base.DatasetBase.__init__
#   File "rasterio/_base.pyx", line 221, in rasterio._base.open_dataset
#   File "rasterio/_err.pyx", line 359, in rasterio._err.exc_wrap_pointer
# rasterio._err.CPLE_HttpResponseError: HTTP response code: 404
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 202, in _add_projection_extension
#     with rasterio.open(href) as src:
#          ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/.venv/lib/python3.12/site-packages/rasterio/env.py", line 463, in wrapper
#     return f(*args, **kwds)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/.venv/lib/python3.12/site-packages/rasterio/__init__.py", line 356, in open
#     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "rasterio/_base.pyx", line 312, in rasterio._base.DatasetBase.__init__
# rasterio.errors.RasterioIOError: HTTP response code: 404
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/var/folders/g7/5vynv9md5dz_pzng6cjn6xvc0000gn/T/ipykernel_13087/3052829065.py", line 26, in <module>
#     stac_item = future.result()
#                 ^^^^^^^^^^^^^^^
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/g7/5vynv9md5dz_pzng6cjn6xvc0000gn/T/ipykernel_13087/3052829065.py", line 9, in process_metadata_to_stac
#     return create_item(oam_item_sanitized)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 187, in create_item
#     _add_projection_extension(item, ["image"])
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 205, in _add_projection_extension
#     raise AssetNotFoundError(f"Asset does not exist at {href}") from e
# stactools.hotosm.exceptions.AssetNotFoundError: Asset does not exist at http://oin-hotosm-staging.s3.amazonaws.com/202/5984519000239f00149f2ea4/0/6494d8ea-d118-40dc-acfc-9184868da540.tif
# ERROR:root:Could not generate STAC Item for 5bcf4a365a9ef7cb5d8a2beb
# Traceback (most recent call last):
#   File "rasterio/_base.pyx", line 310, in rasterio._base.DatasetBase.__init__
#   File "rasterio/_base.pyx", line 221, in rasterio._base.open_dataset
#   File "rasterio/_err.pyx", line 359, in rasterio._err.exc_wrap_pointer
# rasterio._err.CPLE_HttpResponseError: HTTP response code: 404
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 202, in _add_projection_extension
#     with rasterio.open(href) as src:
#          ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/.venv/lib/python3.12/site-packages/rasterio/env.py", line 463, in wrapper
#     return f(*args, **kwds)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/.venv/lib/python3.12/site-packages/rasterio/__init__.py", line 356, in open
#     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "rasterio/_base.pyx", line 312, in rasterio._base.DatasetBase.__init__
# rasterio.errors.RasterioIOError: HTTP response code: 404
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/var/folders/g7/5vynv9md5dz_pzng6cjn6xvc0000gn/T/ipykernel_13087/3052829065.py", line 26, in <module>
#     stac_item = future.result()
#                 ^^^^^^^^^^^^^^^
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/g7/5vynv9md5dz_pzng6cjn6xvc0000gn/T/ipykernel_13087/3052829065.py", line 9, in process_metadata_to_stac
#     return create_item(oam_item_sanitized)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 187, in create_item
#     _add_projection_extension(item, ["image"])
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 205, in _add_projection_extension
#     raise AssetNotFoundError(f"Asset does not exist at {href}") from e
# stactools.hotosm.exceptions.AssetNotFoundError: Asset does not exist at http://oin-hotosm-staging.s3.amazonaws.com/201/5984494ef6c53f0014223d89/0/d3a51a27-2bf8-40c6-9c55-76247af83e20.tif
# ERROR:root:Could not generate STAC Item for 5bcf4a365a9ef7cb5d8a2bc2
# Traceback (most recent call last):
#   File "rasterio/_base.pyx", line 310, in rasterio._base.DatasetBase.__init__
#   File "rasterio/_base.pyx", line 221, in rasterio._base.open_dataset
#   File "rasterio/_err.pyx", line 359, in rasterio._err.exc_wrap_pointer
# rasterio._err.CPLE_HttpResponseError: HTTP response code: 404
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 202, in _add_projection_extension
#     with rasterio.open(href) as src:
#          ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/.venv/lib/python3.12/site-packages/rasterio/env.py", line 463, in wrapper
#     return f(*args, **kwds)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/.venv/lib/python3.12/site-packages/rasterio/__init__.py", line 356, in open
#     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "rasterio/_base.pyx", line 312, in rasterio._base.DatasetBase.__init__
# rasterio.errors.RasterioIOError: HTTP response code: 404
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/var/folders/g7/5vynv9md5dz_pzng6cjn6xvc0000gn/T/ipykernel_13087/3052829065.py", line 26, in <module>
#     stac_item = future.result()
#                 ^^^^^^^^^^^^^^^
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/g7/5vynv9md5dz_pzng6cjn6xvc0000gn/T/ipykernel_13087/3052829065.py", line 9, in process_metadata_to_stac
#     return create_item(oam_item_sanitized)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 187, in create_item
#     _add_projection_extension(item, ["image"])
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 205, in _add_projection_extension
#     raise AssetNotFoundError(f"Asset does not exist at {href}") from e
# stactools.hotosm.exceptions.AssetNotFoundError: Asset does not exist at http://oin-hotosm-staging.s3.amazonaws.com/201/598448d0f6c53f0014223d7f/0/f38f76ee-e8bb-4042-815a-9b918515618f.tif
# ERROR:root:Could not generate STAC Item for 5bcf4a355a9ef7cb5d8a2baa
# Traceback (most recent call last):
#   File "rasterio/_base.pyx", line 310, in rasterio._base.DatasetBase.__init__
#   File "rasterio/_base.pyx", line 221, in rasterio._base.open_dataset
#   File "rasterio/_err.pyx", line 359, in rasterio._err.exc_wrap_pointer
# rasterio._err.CPLE_HttpResponseError: HTTP response code: 404
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 202, in _add_projection_extension
#     with rasterio.open(href) as src:
#          ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/.venv/lib/python3.12/site-packages/rasterio/env.py", line 463, in wrapper
#     return f(*args, **kwds)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/.venv/lib/python3.12/site-packages/rasterio/__init__.py", line 356, in open
#     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "rasterio/_base.pyx", line 312, in rasterio._base.DatasetBase.__init__
# rasterio.errors.RasterioIOError: HTTP response code: 404
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/var/folders/g7/5vynv9md5dz_pzng6cjn6xvc0000gn/T/ipykernel_13087/3052829065.py", line 26, in <module>
#     stac_item = future.result()
#                 ^^^^^^^^^^^^^^^
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/g7/5vynv9md5dz_pzng6cjn6xvc0000gn/T/ipykernel_13087/3052829065.py", line 9, in process_metadata_to_stac
#     return create_item(oam_item_sanitized)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 187, in create_item
#     _add_projection_extension(item, ["image"])
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 205, in _add_projection_extension
#     raise AssetNotFoundError(f"Asset does not exist at {href}") from e
# stactools.hotosm.exceptions.AssetNotFoundError: Asset does not exist at http://oin-hotosm-staging.s3.amazonaws.com/201/598448d0f6c53f0014223d7f/0/f38f76ee-e8bb-4042-815a-9b918515618f.tif
# ERROR:root:Could not generate STAC Item for 5bcf4a365a9ef7cb5d8a2bb9
# Traceback (most recent call last):
#   File "rasterio/_base.pyx", line 310, in rasterio._base.DatasetBase.__init__
#   File "rasterio/_base.pyx", line 221, in rasterio._base.open_dataset
#   File "rasterio/_err.pyx", line 359, in rasterio._err.exc_wrap_pointer
# rasterio._err.CPLE_HttpResponseError: HTTP response code: 404
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 202, in _add_projection_extension
#     with rasterio.open(href) as src:
#          ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/.venv/lib/python3.12/site-packages/rasterio/env.py", line 463, in wrapper
#     return f(*args, **kwds)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/.venv/lib/python3.12/site-packages/rasterio/__init__.py", line 356, in open
#     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "rasterio/_base.pyx", line 312, in rasterio._base.DatasetBase.__init__
# rasterio.errors.RasterioIOError: HTTP response code: 404
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/var/folders/g7/5vynv9md5dz_pzng6cjn6xvc0000gn/T/ipykernel_13087/3052829065.py", line 26, in <module>
#     stac_item = future.result()
#                 ^^^^^^^^^^^^^^^
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/g7/5vynv9md5dz_pzng6cjn6xvc0000gn/T/ipykernel_13087/3052829065.py", line 9, in process_metadata_to_stac
#     return create_item(oam_item_sanitized)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 187, in create_item
#     _add_projection_extension(item, ["image"])
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 205, in _add_projection_extension
#     raise AssetNotFoundError(f"Asset does not exist at {href}") from e
# stactools.hotosm.exceptions.AssetNotFoundError: Asset does not exist at http://oin-hotosm-staging.s3.amazonaws.com/201/598448d0f6c53f0014223d7f/0/f38f76ee-e8bb-4042-815a-9b918515618f.tif
# ERROR:root:Could not generate STAC Item for 5bcf4a345a9ef7cb5d8a2b69
# Traceback (most recent call last):
#   File "rasterio/_base.pyx", line 310, in rasterio._base.DatasetBase.__init__
#   File "rasterio/_base.pyx", line 221, in rasterio._base.open_dataset
#   File "rasterio/_err.pyx", line 359, in rasterio._err.exc_wrap_pointer
# rasterio._err.CPLE_HttpResponseError: HTTP response code: 404
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 202, in _add_projection_extension
#     with rasterio.open(href) as src:
#          ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/.venv/lib/python3.12/site-packages/rasterio/env.py", line 463, in wrapper
#     return f(*args, **kwds)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/.venv/lib/python3.12/site-packages/rasterio/__init__.py", line 356, in open
#     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "rasterio/_base.pyx", line 312, in rasterio._base.DatasetBase.__init__
# rasterio.errors.RasterioIOError: HTTP response code: 404
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/var/folders/g7/5vynv9md5dz_pzng6cjn6xvc0000gn/T/ipykernel_13087/3052829065.py", line 26, in <module>
#     stac_item = future.result()
#                 ^^^^^^^^^^^^^^^
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/g7/5vynv9md5dz_pzng6cjn6xvc0000gn/T/ipykernel_13087/3052829065.py", line 9, in process_metadata_to_stac
#     return create_item(oam_item_sanitized)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 187, in create_item
#     _add_projection_extension(item, ["image"])
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 205, in _add_projection_extension
#     raise AssetNotFoundError(f"Asset does not exist at {href}") from e
# stactools.hotosm.exceptions.AssetNotFoundError: Asset does not exist at http://oin-hotosm-staging.s3.amazonaws.com/196/597b7d18be6b35001330f605/0/bed5ac23-5cef-4a4c-ac84-85103c2c4eb4.tif
# ERROR:root:Could not generate STAC Item for 5bcf4a365a9ef7cb5d8a2bdc
# Traceback (most recent call last):
#   File "rasterio/_base.pyx", line 310, in rasterio._base.DatasetBase.__init__
#   File "rasterio/_base.pyx", line 221, in rasterio._base.open_dataset
#   File "rasterio/_err.pyx", line 359, in rasterio._err.exc_wrap_pointer
# rasterio._err.CPLE_HttpResponseError: HTTP response code: 404
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 202, in _add_projection_extension
#     with rasterio.open(href) as src:
#          ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/.venv/lib/python3.12/site-packages/rasterio/env.py", line 463, in wrapper
#     return f(*args, **kwds)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/.venv/lib/python3.12/site-packages/rasterio/__init__.py", line 356, in open
#     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "rasterio/_base.pyx", line 312, in rasterio._base.DatasetBase.__init__
# rasterio.errors.RasterioIOError: HTTP response code: 404
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/var/folders/g7/5vynv9md5dz_pzng6cjn6xvc0000gn/T/ipykernel_13087/3052829065.py", line 26, in <module>
#     stac_item = future.result()
#                 ^^^^^^^^^^^^^^^
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/g7/5vynv9md5dz_pzng6cjn6xvc0000gn/T/ipykernel_13087/3052829065.py", line 9, in process_metadata_to_stac
#     return create_item(oam_item_sanitized)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 187, in create_item
#     _add_projection_extension(item, ["image"])
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 205, in _add_projection_extension
#     raise AssetNotFoundError(f"Asset does not exist at {href}") from e
# stactools.hotosm.exceptions.AssetNotFoundError: Asset does not exist at http://oin-hotosm-staging.s3.amazonaws.com/201/5984494ef6c53f0014223d89/0/d3a51a27-2bf8-40c6-9c55-76247af83e20.tif
# ERROR:root:Could not generate STAC Item for 5bcf4a355a9ef7cb5d8a2b9b
# Traceback (most recent call last):
#   File "rasterio/_base.pyx", line 310, in rasterio._base.DatasetBase.__init__
#   File "rasterio/_base.pyx", line 221, in rasterio._base.open_dataset
#   File "rasterio/_err.pyx", line 359, in rasterio._err.exc_wrap_pointer
# rasterio._err.CPLE_HttpResponseError: HTTP response code: 404
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 202, in _add_projection_extension
#     with rasterio.open(href) as src:
#          ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/.venv/lib/python3.12/site-packages/rasterio/env.py", line 463, in wrapper
#     return f(*args, **kwds)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/.venv/lib/python3.12/site-packages/rasterio/__init__.py", line 356, in open
#     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "rasterio/_base.pyx", line 312, in rasterio._base.DatasetBase.__init__
# rasterio.errors.RasterioIOError: HTTP response code: 404
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/var/folders/g7/5vynv9md5dz_pzng6cjn6xvc0000gn/T/ipykernel_13087/3052829065.py", line 26, in <module>
#     stac_item = future.result()
#                 ^^^^^^^^^^^^^^^
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/g7/5vynv9md5dz_pzng6cjn6xvc0000gn/T/ipykernel_13087/3052829065.py", line 9, in process_metadata_to_stac
#     return create_item(oam_item_sanitized)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 187, in create_item
#     _add_projection_extension(item, ["image"])
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 205, in _add_projection_extension
#     raise AssetNotFoundError(f"Asset does not exist at {href}") from e
# stactools.hotosm.exceptions.AssetNotFoundError: Asset does not exist at http://oin-hotosm-staging.s3.amazonaws.com/201/598448fcf6c53f0014223d83/0/41298f56-f1f8-408e-ad78-a32a3b677f0b.tif
# ERROR:root:Could not generate STAC Item for 5bcf4a355a9ef7cb5d8a2b91
# Traceback (most recent call last):
#   File "rasterio/_base.pyx", line 310, in rasterio._base.DatasetBase.__init__
#   File "rasterio/_base.pyx", line 221, in rasterio._base.open_dataset
#   File "rasterio/_err.pyx", line 359, in rasterio._err.exc_wrap_pointer
# rasterio._err.CPLE_HttpResponseError: HTTP response code: 404
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 202, in _add_projection_extension
#     with rasterio.open(href) as src:
#          ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/.venv/lib/python3.12/site-packages/rasterio/env.py", line 463, in wrapper
#     return f(*args, **kwds)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/.venv/lib/python3.12/site-packages/rasterio/__init__.py", line 356, in open
#     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "rasterio/_base.pyx", line 312, in rasterio._base.DatasetBase.__init__
# rasterio.errors.RasterioIOError: HTTP response code: 404
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/var/folders/g7/5vynv9md5dz_pzng6cjn6xvc0000gn/T/ipykernel_13087/3052829065.py", line 26, in <module>
#     stac_item = future.result()
#                 ^^^^^^^^^^^^^^^
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/g7/5vynv9md5dz_pzng6cjn6xvc0000gn/T/ipykernel_13087/3052829065.py", line 9, in process_metadata_to_stac
#     return create_item(oam_item_sanitized)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 187, in create_item
#     _add_projection_extension(item, ["image"])
# ...
#            ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/g7/5vynv9md5dz_pzng6cjn6xvc0000gn/T/ipykernel_13087/3052829065.py", line 9, in process_metadata_to_stac
#     return create_item(oam_item_sanitized)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 187, in create_item
#     _add_projection_extension(item, ["image"])
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 205, in _add_projection_extension
#     raise AssetNotFoundError(f"Asset does not exist at {href}") from e
# stactools.hotosm.exceptions.AssetNotFoundError: Asset does not exist at http://oin-hotosm-staging.s3.amazonaws.com/196/5979b7a82901f900149b4c07/0/a6457678-bc6b-453c-9127-6d480b10b05a.tif
# ERROR:root:Could not generate STAC Item for 660d0b08c055e600014ac432
# Traceback (most recent call last):
#   File "rasterio/_base.pyx", line 310, in rasterio._base.DatasetBase.__init__
#   File "rasterio/_base.pyx", line 221, in rasterio._base.open_dataset
#   File "rasterio/_err.pyx", line 359, in rasterio._err.exc_wrap_pointer
# rasterio._err.CPLE_HttpResponseError: HTTP response code: 404
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 202, in _add_projection_extension
#     with rasterio.open(href) as src:
#          ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/.venv/lib/python3.12/site-packages/rasterio/env.py", line 463, in wrapper
#     return f(*args, **kwds)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/.venv/lib/python3.12/site-packages/rasterio/__init__.py", line 356, in open
#     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "rasterio/_base.pyx", line 312, in rasterio._base.DatasetBase.__init__
# rasterio.errors.RasterioIOError: HTTP response code: 404
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/var/folders/g7/5vynv9md5dz_pzng6cjn6xvc0000gn/T/ipykernel_13087/3052829065.py", line 26, in <module>
#     stac_item = future.result()
#                 ^^^^^^^^^^^^^^^
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/g7/5vynv9md5dz_pzng6cjn6xvc0000gn/T/ipykernel_13087/3052829065.py", line 9, in process_metadata_to_stac
#     return create_item(oam_item_sanitized)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 187, in create_item
#     _add_projection_extension(item, ["image"])
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 205, in _add_projection_extension
#     raise AssetNotFoundError(f"Asset does not exist at {href}") from e
# stactools.hotosm.exceptions.AssetNotFoundError: Asset does not exist at http://oin-hotosm-staging.s3.amazonaws.com/195/59798f88e25b8f0013b42e53/0/eed3156e-ef6e-44db-aa18-c00515530857.tif
# ERROR:root:Could not generate STAC Item for 5bcf4a365a9ef7cb5d8a2bd4
# Traceback (most recent call last):
#   File "rasterio/_base.pyx", line 310, in rasterio._base.DatasetBase.__init__
#   File "rasterio/_base.pyx", line 221, in rasterio._base.open_dataset
#   File "rasterio/_err.pyx", line 359, in rasterio._err.exc_wrap_pointer
# rasterio._err.CPLE_HttpResponseError: HTTP response code: 404
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 202, in _add_projection_extension
#     with rasterio.open(href) as src:
#          ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/.venv/lib/python3.12/site-packages/rasterio/env.py", line 463, in wrapper
#     return f(*args, **kwds)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/.venv/lib/python3.12/site-packages/rasterio/__init__.py", line 356, in open
#     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "rasterio/_base.pyx", line 312, in rasterio._base.DatasetBase.__init__
# rasterio.errors.RasterioIOError: HTTP response code: 404
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/var/folders/g7/5vynv9md5dz_pzng6cjn6xvc0000gn/T/ipykernel_13087/3052829065.py", line 26, in <module>
#     stac_item = future.result()
#                 ^^^^^^^^^^^^^^^
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/g7/5vynv9md5dz_pzng6cjn6xvc0000gn/T/ipykernel_13087/3052829065.py", line 9, in process_metadata_to_stac
#     return create_item(oam_item_sanitized)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 187, in create_item
#     _add_projection_extension(item, ["image"])
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 205, in _add_projection_extension
#     raise AssetNotFoundError(f"Asset does not exist at {href}") from e
# stactools.hotosm.exceptions.AssetNotFoundError: Asset does not exist at http://oin-hotosm-staging.s3.amazonaws.com/191/597465689a83f3001367e5c6/0/9064264a-8e0b-4872-91b5-935b267a0d55.tif
# ERROR:root:Could not generate STAC Item for 660d1166c055e600014ac439
# Traceback (most recent call last):
#   File "rasterio/_base.pyx", line 310, in rasterio._base.DatasetBase.__init__
#   File "rasterio/_base.pyx", line 221, in rasterio._base.open_dataset
#   File "rasterio/_err.pyx", line 359, in rasterio._err.exc_wrap_pointer
# rasterio._err.CPLE_HttpResponseError: HTTP response code: 404
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 202, in _add_projection_extension
#     with rasterio.open(href) as src:
#          ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/.venv/lib/python3.12/site-packages/rasterio/env.py", line 463, in wrapper
#     return f(*args, **kwds)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/.venv/lib/python3.12/site-packages/rasterio/__init__.py", line 356, in open
#     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "rasterio/_base.pyx", line 312, in rasterio._base.DatasetBase.__init__
# rasterio.errors.RasterioIOError: HTTP response code: 404
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/var/folders/g7/5vynv9md5dz_pzng6cjn6xvc0000gn/T/ipykernel_13087/3052829065.py", line 26, in <module>
#     stac_item = future.result()
#                 ^^^^^^^^^^^^^^^
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/g7/5vynv9md5dz_pzng6cjn6xvc0000gn/T/ipykernel_13087/3052829065.py", line 9, in process_metadata_to_stac
#     return create_item(oam_item_sanitized)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 187, in create_item
#     _add_projection_extension(item, ["image"])
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 205, in _add_projection_extension
#     raise AssetNotFoundError(f"Asset does not exist at {href}") from e
# stactools.hotosm.exceptions.AssetNotFoundError: Asset does not exist at http://oin-hotosm-staging.s3.amazonaws.com/195/59798f88e25b8f0013b42e53/0/eed3156e-ef6e-44db-aa18-c00515530857.tif
# ERROR:root:Could not generate STAC Item for 5bcf4a385a9ef7cb5d8a2c72
# Traceback (most recent call last):
#   File "rasterio/_base.pyx", line 310, in rasterio._base.DatasetBase.__init__
#   File "rasterio/_base.pyx", line 221, in rasterio._base.open_dataset
#   File "rasterio/_err.pyx", line 359, in rasterio._err.exc_wrap_pointer
# rasterio._err.CPLE_HttpResponseError: HTTP response code: 404
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 202, in _add_projection_extension
#     with rasterio.open(href) as src:
#          ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/.venv/lib/python3.12/site-packages/rasterio/env.py", line 463, in wrapper
#     return f(*args, **kwds)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/.venv/lib/python3.12/site-packages/rasterio/__init__.py", line 356, in open
#     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "rasterio/_base.pyx", line 312, in rasterio._base.DatasetBase.__init__
# rasterio.errors.RasterioIOError: HTTP response code: 404
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/var/folders/g7/5vynv9md5dz_pzng6cjn6xvc0000gn/T/ipykernel_13087/3052829065.py", line 26, in <module>
#     stac_item = future.result()
#                 ^^^^^^^^^^^^^^^
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/g7/5vynv9md5dz_pzng6cjn6xvc0000gn/T/ipykernel_13087/3052829065.py", line 9, in process_metadata_to_stac
#     return create_item(oam_item_sanitized)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 187, in create_item
#     _add_projection_extension(item, ["image"])
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 205, in _add_projection_extension
#     raise AssetNotFoundError(f"Asset does not exist at {href}") from e
# stactools.hotosm.exceptions.AssetNotFoundError: Asset does not exist at http://oin-hotosm-staging.s3.amazonaws.com/195/59798f88e25b8f0013b42e53/0/eed3156e-ef6e-44db-aa18-c00515530857.tif
# ERROR:root:Could not generate STAC Item for 5bcf4a385a9ef7cb5d8a2c37
# Traceback (most recent call last):
#   File "rasterio/_base.pyx", line 310, in rasterio._base.DatasetBase.__init__
#   File "rasterio/_base.pyx", line 221, in rasterio._base.open_dataset
#   File "rasterio/_err.pyx", line 359, in rasterio._err.exc_wrap_pointer
# rasterio._err.CPLE_HttpResponseError: HTTP response code: 404
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 202, in _add_projection_extension
#     with rasterio.open(href) as src:
#          ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/.venv/lib/python3.12/site-packages/rasterio/env.py", line 463, in wrapper
#     return f(*args, **kwds)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/.venv/lib/python3.12/site-packages/rasterio/__init__.py", line 356, in open
#     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "rasterio/_base.pyx", line 312, in rasterio._base.DatasetBase.__init__
# rasterio.errors.RasterioIOError: HTTP response code: 404
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/var/folders/g7/5vynv9md5dz_pzng6cjn6xvc0000gn/T/ipykernel_13087/3052829065.py", line 26, in <module>
#     stac_item = future.result()
#                 ^^^^^^^^^^^^^^^
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/Users/ceholden/.local/share/uv/python/cpython-3.12.7-macos-aarch64-none/lib/python3.12/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/g7/5vynv9md5dz_pzng6cjn6xvc0000gn/T/ipykernel_13087/3052829065.py", line 9, in process_metadata_to_stac
#     return create_item(oam_item_sanitized)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 187, in create_item
#     _add_projection_extension(item, ["image"])
#   File "/Users/ceholden/Documents/HOTOSM/stactools-hotosm/src/stactools/hotosm/stac.py", line 205, in _add_projection_extension
#     raise AssetNotFoundError(f"Asset does not exist at {href}") from e
# stactools.hotosm.exceptions.AssetNotFoundError: Asset does not exist at http://oin-hotosm-staging.s3.amazonaws.com/195/59798f88e25b8f0013b42e53/0/eed3156e-ef6e-44db-aa18-c00515530857.tif

# %%
print(f"Converted {len(stac_items)} of {total} metadata entries to STAC Items")
# Out:
# Converted 17690 of 17745 metadata entries to STAC Items

# %% [markdown]
# ### Write to NDJSON for ingestion into (PgSTAC) STAC Catalog

# %%
import json

with open("openaerialmap.ndjson", "w") as dst:
    for item in stac_items:
        item_json = json.dumps(item.to_dict())
        dst.write(f"{item_json}\n")
